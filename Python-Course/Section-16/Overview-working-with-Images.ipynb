# %%
from PIL import Image

# %%
mac = Image.open('images\\example.jpg')

# %%
mac.crop((0, 0, 100, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
pencils = Image.open('images\\pencils.jpg')

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
# TOP PENCILS
x = 0
y = 0

w = 1950 / 3
h = 1300 / 10

pencils.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
halfway = 1993 / 2

x = halfway - 200
w = halfway + 200

y = 800
h = 1257

# %%
mac.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x457>

# %%
computer = mac.crop((x, y, w, h))

# Paste in the actual image
mac.paste(im=computer, box=(0, 0))

# %%
mac.resize((3000, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x500>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1993x1257>

# %%
red = Image.open('images\\red_color.jpg')

# %%
blue = Image.open('images\\blue_color.png')

# %%
# transparent
blue.putalpha(0)

# %%
blue.paste(im=red, box=(0, 0), mask=red)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 blue.paste(im=red, box=(0, 0), mask=red)
#
# File c:\Users\mario\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:1738, in Image.paste(self, im, box, mask)
#    1736 if mask:
#    1737     mask.load()
# -> 1738     self.im.paste(im, box, mask.im)
#    1739 else:
#    1740     self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
# to save
# blue.save('images\\purple.png')
